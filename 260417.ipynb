# %% [markdown]
# <a href="https://colab.research.google.com/github/MattKim98/aipython/blob/main/260417.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cafe_menu = {
    "Americano": 4000,
    "Cafe Latte": 4500,
    "Cappuccino": 4500,
    "Vanilla Latte": 5000,
    "Caramel Macchiato": 5000,
    "Espresso": 3500,
    "Chocolate Latte": 5500,
    "Matcha Latte": 5500,
    "Grapefruit Ade": 6000,
    "Lemon Ade": 6000
}

display(cafe_menu)
for key, value in cafe_menu.items():
  print(f"{key}의 가격은 {value}원입니다.")
# Out:
# {'Americano': 4000,
#  'Cafe Latte': 4500,
#  'Cappuccino': 4500,
#  'Vanilla Latte': 5000,
#  'Caramel Macchiato': 5000,
#  'Espresso': 3500,
#  'Chocolate Latte': 5500,
#  'Matcha Latte': 5500,
#  'Grapefruit Ade': 6000,
#  'Lemon Ade': 6000}
# Americano의 가격은 4000원입니다.
# Cafe Latte의 가격은 4500원입니다.
# Cappuccino의 가격은 4500원입니다.
# Vanilla Latte의 가격은 5000원입니다.
# Caramel Macchiato의 가격은 5000원입니다.
# Espresso의 가격은 3500원입니다.
# Chocolate Latte의 가격은 5500원입니다.
# Matcha Latte의 가격은 5500원입니다.
# Grapefruit Ade의 가격은 6000원입니다.
# Lemon Ade의 가격은 6000원입니다.

# %%
countries_capitals = {
    "United States": "Washington, D.C.",
    "Canada": "Ottawa",
    "Mexico": "Mexico City",
    "Brazil": "Brasília",
    "Argentina": "Buenos Aires",
    "United Kingdom": "London",
    "France": "Paris",
    "Germany": "Berlin",
    "Italy": "Rome",
    "Spain": "Madrid",
    "China": "Beijing",
    "India": "New Delhi",
    "Japan": "Tokyo",
    "South Korea": "Seoul",
    "Australia": "Canberra",
    "Egypt": "Cairo",
    "South Africa": "Pretoria",
    "Nigeria": "Abuja",
    "Russia": "Moscow",
    "Saudi Arabia": "Riyadh"
}

display(countries_capitals)
for key, value in countries_capitals.items():
  print(f"{key}의 수도는 {value}입니다.")
# Out:
# {'United States': 'Washington, D.C.',
#  'Canada': 'Ottawa',
#  'Mexico': 'Mexico City',
#  'Brazil': 'Brasília',
#  'Argentina': 'Buenos Aires',
#  'United Kingdom': 'London',
#  'France': 'Paris',
#  'Germany': 'Berlin',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'China': 'Beijing',
#  'India': 'New Delhi',
#  'Japan': 'Tokyo',
#  'South Korea': 'Seoul',
#  'Australia': 'Canberra',
#  'Egypt': 'Cairo',
#  'South Africa': 'Pretoria',
#  'Nigeria': 'Abuja',
#  'Russia': 'Moscow',
#  'Saudi Arabia': 'Riyadh'}
# United States의 수도는 Washington, D.C.입니다.
# Canada의 수도는 Ottawa입니다.
# Mexico의 수도는 Mexico City입니다.
# Brazil의 수도는 Brasília입니다.
# Argentina의 수도는 Buenos Aires입니다.
# United Kingdom의 수도는 London입니다.
# France의 수도는 Paris입니다.
# Germany의 수도는 Berlin입니다.
# Italy의 수도는 Rome입니다.
# Spain의 수도는 Madrid입니다.
# China의 수도는 Beijing입니다.
# India의 수도는 New Delhi입니다.
# Japan의 수도는 Tokyo입니다.
# South Korea의 수도는 Seoul입니다.
# Australia의 수도는 Canberra입니다.
# Egypt의 수도는 Cairo입니다.
# South Africa의 수도는 Pretoria입니다.
# ...

# %%
print("Cafe Menu Items and Prices:")
for item, price in cafe_menu.items():
    print(f"Menu Item: {item}, Price: {price}")
